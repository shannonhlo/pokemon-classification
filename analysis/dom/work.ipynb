# %%
#----------------------------------------------
# Load dependencies
#----------------------------------------------
import pandas as pd
import base64
import re
import numpy as np
import string
import unicodedata
import nltk
import os
import streamlit as st
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

nltk.download('stopwords')


#----------------------------------------------
# Define variables
#----------------------------------------------

# English stopwords
stopwords_en = nltk.corpus.stopwords.words('english')

# French stopwords
stopwords_fr = nltk.corpus.stopwords.words('french')

#----------------------------------------------
# Define functions
#----------------------------------------------

# Helper function
def clean_cols(cols):
    cols_clean1 = cols.str.replace(' ', '_').str.replace('.', '')
    cols_clean2 = cols_clean1.str.replace('.', '') 
    cols_clean3 = [col.lower() for col in cols_clean2]
    return cols_clean3
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\domen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Read in teams & accounts CSVs
df = pd.read_csv('C:/Users/domen/github/pokemon_classification/assets/style_names.csv')
df = df[["MASTER_STYLE", "STYLE_NAME", "UNIQUE_SKU"]]
df.head(4)
# Out:
#               MASTER_STYLE                              STYLE_NAME  UNIQUE_SKU
# 0               ENERGY BRA                              ENERGY BRA      2084.0
# 1            DEFINE JACKET                           DEFINE JACKET      1469.0
# 2            ALIGN PANT II  ALIGN PANT II - ES EC - DNU AFTER SP20       333.0
# 3  FLY AWAY TAMER HEADBAND              FLY AWAY TAMER HEADBAND II       123.0

# %%
# Clean data

# clean column names
df.columns = clean_cols(df.columns)

# convert columns with string values to lower
df['master_style'] = df.master_style.str.lower()
df['style_name'] = df.style_name.str.lower()
df.head(4)
# Out:
# <ipython-input-11-8928dc62d2f1>:34: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   cols_clean1 = cols.str.replace(' ', '_').str.replace('.', '')
# <ipython-input-11-8928dc62d2f1>:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   cols_clean2 = cols_clean1.str.replace('.', '')
#               master_style                              style_name  unique_sku
# 0               energy bra                              energy bra      2084.0
# 1            define jacket                           define jacket      1469.0
# 2            align pant ii  align pant ii - es ec - dnu after sp20       333.0
# 3  fly away tamer headband              fly away tamer headband ii       123.0

# %%
# Text analytics functions

def round1_text_clean(text):
    text = ' ' + text # added space because there was some weirdness for first word (strip later)
    text = text.lower() # convert all text to lowercase
    text = re.sub(r'(\s)@\w+', '', text) # remove whole word if starts with @
    text = re.sub(r'(\s)\w*\d\w*\w+', '', text) # remove whole word if starts with number
    text = re.sub(r'https\:\/\/t\.co\/*\w*', '', text) # remove https links
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) # removes punctuation
    text = re.sub('\[.*?\]', '', text) # removes text in square brackets
    text = text.replace(" ins ", '') # replace apostrophes with empty string
    #text = re.sub('\w*\d\w*', '', text) # remove whole word if starts with number
    #text = re.sub(r'(\s)#\w+', '', text) # remove whole word if starts with #
    text = text.strip() # strip text
    return text

# Function 7b
#-------------
text_clean_round1 = lambda x: round1_text_clean(x)

# Function 8
#-------------
def text_clean_round2(text):
    """
    A simple function to clean up the data. All the words that
    are not designated as a stop word is then lemmatized after
    encoding and basic regex parsing are performed.
    """
    nltk.download('wordnet')
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')
    text = (unicodedata.normalize('NFKD', text)
    .encode('ascii', 'ignore')
    .decode('utf-8', 'ignore'))
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# Function 9
#-------------
def text_clean_round3(text):
    #TODO: add emoticons and emojis to this!
    # Load in stopwords
    stopwords_en = nltk.corpus.stopwords.words('english')
    stopwords_fr = nltk.corpus.stopwords.words('french')
    stopwords = stopwords_en + stopwords_fr
    # Create pre-clean character count feature
    text = text.apply(lambda x: " ".join(x for x in x.split() if x not in stopwords))
    return text

# Function 10a
#-----------------
def tweets_ngrams(n, top_n, df):
    """
    Generates series of top ngrams
    n: number of words in the ngram
    top_n: number of ngrams with highest frequencies
    """
    text = df.text
    words = text_clean_round2(''.join(str(text.tolist())))
    result = (pd.Series(data = nltk.ngrams(words, n), name = 'frequency').value_counts())[:top_n]
    return result.to_frame()

# Function 10b
#-----------------
def all_ngrams(top_n, df):
    text = df.text
    words = text_clean_round2(''.join(str(text.tolist())))
    unigram = ((pd.Series(data = nltk.ngrams(words, 1), name = 'freq').value_counts())[:top_n]).to_frame()
    unigram['ngram'] = 'unigram'
    bigram = ((pd.Series(data = nltk.ngrams(words, 2), name = 'freq').value_counts())[:top_n]).to_frame()
    bigram['ngram'] = 'bigram'
    trigram = ((pd.Series(data = nltk.ngrams(words, 3), name = 'freq').value_counts())[:top_n]).to_frame()
    trigram['ngram'] = 'trigram'
    result = unigram.append([bigram, trigram])
    result['ngram_nm'] = result.index
    return result

# %%
# create a new column from master_style called text
df['master_style'] = df.master_style.astype(str)
df['text'] = df.master_style

# prepare text for text cleaning (remove punctuation, numbers, etc.)
df['text'] = df.text.apply(text_clean_round1)
df['text'] = text_clean_round3(df.text)

df[df.master_style.str.contains('ins')].head(50)
# Out:
#                                     master_style  \
# 7                      wunder train tight 25 ins
# 70                      wunder train short 6 ins
# 149                     wunder train crop 21 ins
# 180                     wunder train short 8 ins
# 211                     wunder train crop 23 ins
# 233                    wunder train tight 28 ins
# 714                             inspire tight ii
# 903                        instill hr tight 25in
# 946               wunder under crop hr 23 inseam
# 997                     wunder train short 4 ins
# 1816                 su18 short 3 (hr 10 inseam)
# 1864                         reinstate ls henley
# 2610                             mainstay jogger
# 2668                         run inspire crop ii
# 3347  more than modal crew refabrication lw3cins
# 3375                   wunder train tight 25 ins
# 3413                 rain haven jacket insulated
# 3491              wunder under crop hr 23 inseam
# 3614                              mainstay short
# 3762              wunder under crop hr 23 inseam
# 3774                          this instant short
# 3942                           mainstay dopp kit
# 3965              wunder under crop hr 23 inseam
# 4023                   wunder train tight 25 ins
# 4159                           mainstay backpack
# 4462                          ft inspire crop ii
# 4559                             mainstay jacket
# 4719                  storm break coat insulated
# 4855              wunder under crop hr 23 inseam
# 4983                    wunder train crop 21 ins
# 5265                    wunder train crop 21 ins
# 5289                    mainstay pullover hoodie
# 5733              wunder under crop hr 23 inseam
# 5751                   wunder train tight 25 ins
# 5796                             mainstay duffle
# 5867             chill time insulated h2o bottle
# 5909                    wunder train short 4 ins
# 6091                                  insta vest
# 6201              wunder under crop hr 23 inseam
# 6696                  midweight insulated hoodie
# 6827                 against convention ls shirt
# 6887              wunder under crop hr 23 inseam
# 7149                    go cozy insulated jacket
# 7346              insulated quilted pullover jkt
# 7404                        cozy instincts dress
# 7623              wunder under crop hr 23 inseam
# 7640                         run inspire crop ii
# 7813              wunder under crop hr 23 inseam
# 7857                    wunder train short 6 ins
# 8196                  mainstay hybrid buttondown
#
#                                              style_name  unique_sku  \
# 7                            wunder train hr tight 25in       594.0
# 70                            wunder train hr short 6in       380.0
# 149                           wunder train hr crop 21in       268.0
# 180                           wunder train hr short 8in       264.0
# 211                           wunder train hr crop 23in       317.0
# 233                          wunder train hr tight 28in       193.0
# 714                                    inspire tight ii       396.0
# 903                               instill hr tight 25in        40.0
# 946            wunder under crop hr 23 inseam fe fullux        69.0
# 997                           wunder train hr short 4in        60.0
# 1816                           on pace short 10 inch hr        18.0
# 1864                          reinstate ls henley - htr        24.0
# 2610                                    mainstay jogger        16.0
# 2668                                    inspire crop ii       224.0
# 3347                                  every moment crew        24.0
# 3375              wunder train hr tight 25in - pu print        16.0
# 3413                        rain haven jacket insulated        30.0
# 3491          dnu wunder under crop hr 23 inseam fullux        24.0
# 3614                                     mainstay short        15.0
# 3762              wunder under crop hr 23 inseam fullux        35.0
# 3774                                 this instant short        32.0
# 3942                                  mainstay dopp kit         2.0
# 3965  wunder under crop hr 23 inseam es fe fullux he...         8.0
# 4023     tie dye wunder train hr tight 25in (fa20 only)         8.0
# 4159                                  mainstay backpack         5.0
# 4462                                    inspire crop ii         6.0
# 4559                                    mainstay jacket        14.0
# 4719                         storm break coat insulated        11.0
# 4855          wunder under crop hr 23 inseam fe fullux         30.0
# 4983      tie dye wunder train hr crop 21in (fa20 only)         8.0
# 5265               wunder train hr crop 21in - pu print         8.0
# 5289                           mainstay pullover hoodie        10.0
# 5733             wunder under crop hr 23 inseam - shine         8.0
# 5751  gd fa20 wunder train tight 25 ins - forest shi...         8.0
# 5796                                    mainstay duffle         2.0
# 5867                        chill time insulated bottle         2.0
# 5909                      dnu wunder train hr short 4in         8.0
# 6091                                         insta vest        12.0
# 6201                     wunder under crop hr 23 inseam        16.0
# 6696                               traverse down jacket        11.0
# 6827                        against convention ls shirt        24.0
# 6887       wunder under crop hr 23 inseam camo jacquard        11.0
# 7149                           go cozy insulated jacket        16.0
# 7346                     insulated quilted pullover jkt        24.0
# 7404                               cozy instincts dress        12.0
# 7623                 wunder under hr crop 23 in - shine         8.0
# 7640                                  run: inspire crop        95.0
# 7813            wunder under crop hr 23 inseam syn jacq         8.0
# 7857               wunder train hr short 6in - pu print         8.0
# 8196                         mainstay hybrid buttondown        11.0
#
#                                 text                          clean_text
# 7             wunder train tight ins              wunder train tight ins
# 70          wunder train short 6 ins            wunder train short 6 ins
# 149            wunder train crop ins               wunder train crop ins
# 180         wunder train short 8 ins            wunder train short 8 ins
# 211            wunder train crop ins               wunder train crop ins
# 233           wunder train tight ins              wunder train tight ins
# 714                 inspire tight ii                    inspire tight ii
# 903                 instill hr tight                    instill hr tight
# 946            wunder crop hr inseam         wunder under crop hr inseam
# 997         wunder train short 4 ins            wunder train short 4 ins
# 1816               short 3 hr inseam                   short 3 hr inseam
# 1864             reinstate ls henley                 reinstate ls henley
# 2610                 mainstay jogger                     mainstay jogger
# 2668             run inspire crop ii                 run inspire crop ii
# 3347        modal crew refabrication  more than modal crew refabrication
# 3375          wunder train tight ins              wunder train tight ins
# 3413           rain jacket insulated         rain haven jacket insulated
# 3491           wunder crop hr inseam         wunder under crop hr inseam
# 3614                  mainstay short                      mainstay short
# 3762           wunder crop hr inseam         wunder under crop hr inseam
# 3774                   instant short                  this instant short
# 3942               mainstay dopp kit                   mainstay dopp kit
# 3965           wunder crop hr inseam         wunder under crop hr inseam
# 4023          wunder train tight ins              wunder train tight ins
# 4159               mainstay backpack                   mainstay backpack
# 4462              ft inspire crop ii                  ft inspire crop ii
# 4559                 mainstay jacket                     mainstay jacket
# 4719      storm break coat insulated          storm break coat insulated
# 4855           wunder crop hr inseam         wunder under crop hr inseam
# 4983           wunder train crop ins               wunder train crop ins
# 5265           wunder train crop ins               wunder train crop ins
# 5289        mainstay pullover hoodie            mainstay pullover hoodie
# 5733           wunder crop hr inseam         wunder under crop hr inseam
# 5751          wunder train tight ins              wunder train tight ins
# 5796                 mainstay duffle                     mainstay duffle
# 5867     chill time insulated bottle         chill time insulated bottle
# 5909        wunder train short 4 ins            wunder train short 4 ins
# 6091                      insta vest                          insta vest
# 6201           wunder crop hr inseam         wunder under crop hr inseam
# 6696      midweight insulated hoodie          midweight insulated hoodie
# 6827             convention ls shirt         against convention ls shirt
# 6887           wunder crop hr inseam         wunder under crop hr inseam
# 7149        go cozy insulated jacket            go cozy insulated jacket
# 7346  insulated quilted pullover jkt      insulated quilted pullover jkt
# 7404            cozy instincts dress                cozy instincts dress
# 7623           wunder crop hr inseam         wunder under crop hr inseam
# 7640             run inspire crop ii                 run inspire crop ii
# 7813           wunder crop hr inseam         wunder under crop hr inseam
# 7857        wunder train short 6 ins            wunder train short 6 ins
# 8196      mainstay hybrid buttondown          mainstay hybrid buttondown

# %%
all_ngrams(1000, df).head(50)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\domen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#               freq    ngram      ngram_nm
# (short,)      1712  unigram      (short,)
# (tank,)       1208  unigram       (tank,)
# (pant,)       1178  unigram       (pant,)
# (tight,)       983  unigram      (tight,)
# (crop,)        975  unigram       (crop,)
# (tech,)        972  unigram       (tech,)
# (jacket,)      887  unigram     (jacket,)
# (run,)         875  unigram        (run,)
# (l,)           837  unigram          (l,)
# (s,)           709  unigram          (s,)
# (bra,)         618  unigram        (bra,)
# (wunder,)      557  unigram     (wunder,)
# (hoodie,)      508  unigram     (hoodie,)
# (swiftly,)     483  unigram    (swiftly,)
# (crew,)        477  unigram       (crew,)
# (tee,)         477  unigram        (tee,)
# (vent,)        469  unigram       (vent,)
# (metal,)       465  unigram      (metal,)
# (hr,)          422  unigram         (hr,)
# (sleeve,)      380  unigram     (sleeve,)
# (ii,)          366  unigram         (ii,)
# (align,)       330  unigram      (align,)
# (lab,)         326  unigram        (lab,)
# (long,)        316  unigram       (long,)
# (speed,)       306  unigram      (speed,)
# (pullover,)    298  unigram   (pullover,)
# (zip,)         295  unigram        (zip,)
# (inch,)        279  unigram       (inch,)
# (jogger,)      279  unigram     (jogger,)
# (sock,)        277  unigram       (sock,)
# (surge,)       272  unigram      (surge,)
# (free,)        271  unigram       (free,)
# (pace,)        270  unigram       (pace,)
# (city,)        240  unigram       (city,)
# (ft,)          228  unigram         (ft,)
# (fast,)        227  unigram       (fast,)
# (racerback,)   226  unigram  (racerback,)
# (train,)       224  unigram      (train,)
# (20,)          220  unigram         (20,)
# (pack,)        220  unigram       (pack,)
# (sweat,)       219  unigram      (sweat,)
# (5,)           215  unigram          (5,)
# (hirise,)      210  unigram     (hirise,)
# (time,)        192  unigram       (time,)
# (love,)        192  unigram       (love,)
# (skirt,)       186  unigram      (skirt,)
# (dress,)       184  unigram      (dress,)
# (wrap,)        172  unigram       (wrap,)
# (fly,)         165  unigram        (fly,)
# (top,)         163  unigram        (top,)
